# %%
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Function to prepare the data
def prepare_data(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size - 1):
        window = data[i:(i + window_size), 0]
        X.append(window)
        y.append(data[i + window_size, 0])
    return np.array(X), np.array(y)

# Download stock data using Yahoo Finance
stock_symbol = 'FR.PA'  # Change this to desired stock symbol
stock_data = yf.download(stock_symbol, start='2013-01-01', end='2022-01-01')
stock_data = stock_data['Open']
pct_change_data = stock_data.pct_change()
pct_change_data = pct_change_data.drop(pct_change_data.index[0])

# Preprocess data
scaler = MinMaxScaler(feature_range=(-1, 1))
scaled_data = scaler.fit_transform(pct_change_data.values.reshape(-1, 1))

# Define window size for time series data
window_size = 30

# Prepare data for LSTM model
X, y = prepare_data(scaled_data, window_size)
X = X.reshape(X.shape[0], X.shape[1], 1)

X_last_price = [sublist[-1][0] for sublist in X]

# Split data into training and testing sets
split = int(0.8 * len(X))
X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]
X_last_price_test = X[split:]

print(f'length of y_train: {len(y_train)}')
print(f'length of y_test: {len(y_test)}')
# Out:
# [*********************100%***********************]  1 of 1 completed
# length of y_train: 1817
# length of y_test: 455

# %%
print(X_train)
print(y_train)
# Out:
# [[[-0.17852352]
#   [-0.29106765]
#   [-0.26104539]
#   ...
#   [-0.16788471]
#   [-0.24811016]
#   [-0.25627899]]
#
#  [[-0.29106765]
#   [-0.26104539]
#   [-0.24632583]
#   ...
#   [-0.24811016]
#   [-0.25627899]
#   [-0.2309367 ]]
#
#  [[-0.26104539]
#   [-0.24632583]
#   [-0.27406397]
#   ...
#   [-0.25627899]
#   [-0.2309367 ]
#   [-0.17797616]]
#
#  ...
#
#  [[-0.37614279]
#   [-0.34260899]
#   [-0.2684205 ]
#   ...
#   [-0.45551694]
#   [-0.62015639]
#   [-0.73152794]]
#
#  [[-0.34260899]
#   [-0.2684205 ]
#   [-0.15117268]
#   ...
#   [-0.62015639]
#   [-0.73152794]
#   [ 1.        ]]
#
#  [[-0.2684205 ]
#   [-0.15117268]
#   [-0.0875759 ]
#   ...
#   [-0.73152794]
#   [ 1.        ]
#   [ 0.13577685]]]
# [-0.2309367  -0.17797616 -0.23682454 ...  1.          0.13577685
#   0.51640454]

# %%
# Build LSTM model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))

model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# 2023-12-29 10:05:39.890325: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/50
# 57/57 [==============================] - 13s 67ms/step - loss: 0.0246
# Epoch 2/50
# 57/57 [==============================] - 3s 53ms/step - loss: 0.0207
# Epoch 3/50
# 57/57 [==============================] - 3s 50ms/step - loss: 0.0209
# Epoch 4/50
# 57/57 [==============================] - 3s 51ms/step - loss: 0.0212
# Epoch 5/50
# 57/57 [==============================] - 5s 84ms/step - loss: 0.0207
# Epoch 6/50
# 57/57 [==============================] - 4s 64ms/step - loss: 0.0209
# Epoch 7/50
# 57/57 [==============================] - 4s 65ms/step - loss: 0.0207
# Epoch 8/50
# 57/57 [==============================] - 3s 58ms/step - loss: 0.0205
# Epoch 9/50
# 57/57 [==============================] - 3s 58ms/step - loss: 0.0206
# Epoch 10/50
# 57/57 [==============================] - 4s 64ms/step - loss: 0.0207
# Epoch 11/50
# 57/57 [==============================] - 3s 61ms/step - loss: 0.0205
# Epoch 12/50
# 57/57 [==============================] - 4s 64ms/step - loss: 0.0206
# Epoch 13/50
# 57/57 [==============================] - 3s 59ms/step - loss: 0.0206
# Epoch 14/50
# 57/57 [==============================] - 3s 58ms/step - loss: 0.0206
# Epoch 15/50
# 57/57 [==============================] - 4s 70ms/step - loss: 0.0205
# Epoch 16/50
# 57/57 [==============================] - 4s 63ms/step - loss: 0.0204
# Epoch 17/50
# 57/57 [==============================] - 4s 70ms/step - loss: 0.0207
# Epoch 18/50
# 57/57 [==============================] - 3s 60ms/step - loss: 0.0206
# Epoch 19/50
# 57/57 [==============================] - 4s 65ms/step - loss: 0.0208
# Epoch 20/50
# 57/57 [==============================] - 4s 75ms/step - loss: 0.0205
# Epoch 21/50
# 57/57 [==============================] - 4s 63ms/step - loss: 0.0205
# Epoch 22/50
# 57/57 [==============================] - 4s 61ms/step - loss: 0.0202
# Epoch 23/50
# 57/57 [==============================] - 4s 70ms/step - loss: 0.0205
# Epoch 24/50
# 57/57 [==============================] - 4s 67ms/step - loss: 0.0206
# Epoch 25/50
# 57/57 [==============================] - 4s 77ms/step - loss: 0.0202
# Epoch 26/50
# 57/57 [==============================] - 3s 59ms/step - loss: 0.0204
# Epoch 27/50
# 57/57 [==============================] - 3s 59ms/step - loss: 0.0205
# Epoch 28/50
# 57/57 [==============================] - 4s 64ms/step - loss: 0.0203
# Epoch 29/50
# 57/57 [==============================] - 4s 71ms/step - loss: 0.0204
# Epoch 30/50
# 57/57 [==============================] - 3s 61ms/step - loss: 0.0203
# Epoch 31/50
# 57/57 [==============================] - 3s 54ms/step - loss: 0.0201
# Epoch 32/50
# 57/57 [==============================] - 3s 57ms/step - loss: 0.0204
# Epoch 33/50
# 57/57 [==============================] - 3s 59ms/step - loss: 0.0203
# Epoch 34/50
# 57/57 [==============================] - 3s 56ms/step - loss: 0.0204
# Epoch 35/50
# 57/57 [==============================] - 3s 49ms/step - loss: 0.0202
# Epoch 36/50
# 57/57 [==============================] - 3s 52ms/step - loss: 0.0204
# Epoch 37/50
# 57/57 [==============================] - 3s 55ms/step - loss: 0.0203
# Epoch 38/50
# 57/57 [==============================] - 3s 54ms/step - loss: 0.0202
# Epoch 39/50
# 57/57 [==============================] - 3s 52ms/step - loss: 0.0203
# Epoch 40/50
# 57/57 [==============================] - 3s 54ms/step - loss: 0.0202
# Epoch 41/50
# 57/57 [==============================] - 3s 54ms/step - loss: 0.0204
# Epoch 42/50
# 57/57 [==============================] - 4s 62ms/step - loss: 0.0201
# Epoch 43/50
# 57/57 [==============================] - 4s 63ms/step - loss: 0.0203
# Epoch 44/50
# 57/57 [==============================] - 4s 63ms/step - loss: 0.0204
# Epoch 45/50
# 57/57 [==============================] - 3s 59ms/step - loss: 0.0203
# Epoch 46/50
# 57/57 [==============================] - 3s 57ms/step - loss: 0.0201
# Epoch 47/50
# 57/57 [==============================] - 4s 63ms/step - loss: 0.0203
# Epoch 48/50
# 57/57 [==============================] - 3s 57ms/step - loss: 0.0202
# Epoch 49/50
# 57/57 [==============================] - 3s 55ms/step - loss: 0.0201
# Epoch 50/50
# 57/57 [==============================] - 3s 59ms/step - loss: 0.0200

# %%
# Evaluate the model
predicted_price = model.predict(X_test)
predicted_price = scaler.inverse_transform(predicted_price)
real_price = scaler.inverse_transform(y_test.reshape(-1, 1))
last_price = scaler.inverse_transform(X_last_price_test[:, -1, :])

predicted_price_df = pd.DataFrame(predicted_price, columns=['predicted_price'])
real_price_df = pd.DataFrame(real_price, columns=['real_price'])
last_price_df = pd.DataFrame(last_price, columns=['last_price'])

compare_df = pd.concat([last_price_df, predicted_price_df, real_price_df], axis='columns')
compare_df['real_trend_up'] = (compare_df['real_price'] > 0)
compare_df['predicted_trend_up'] = (compare_df['predicted_price'] > 0)
compare_df['true_prediction'] = (compare_df['real_trend_up'] == compare_df['predicted_trend_up'])

accuracy = compare_df['true_prediction'].sum() / len(compare_df['true_prediction'])
print(f'accuracy: {accuracy}')
# Out:
# accuracy: 0.4857142857142857

# %%
compare_df.head(30)
# Out:
#     last_price  predicted_price  real_price  real_trend_up  \
# 0     0.115858         0.011351    0.114861           True
# 1     0.114861         0.012281   -0.040454          False
# 2    -0.040454         0.009125   -0.014255          False
# 3    -0.014255         0.004825   -0.050769          False
# 4    -0.050769         0.000538   -0.034360          False
# 5    -0.034360        -0.002356    0.017120           True
# 6     0.017120        -0.002735   -0.050165          False
# 7    -0.050165        -0.003038    0.005559           True
# 8     0.005559        -0.002179    0.013822           True
# 9     0.013822        -0.000651    0.062713           True
# 10    0.062713         0.001894    0.035920           True
# 11    0.035920         0.003699    0.039009           True
# 12    0.039009         0.004667    0.039630           True
# 13    0.039630         0.004977   -0.063915          False
# 14   -0.063915         0.002921   -0.049296          False
# 15   -0.049296         0.000375    0.001610           True
# 16    0.001610        -0.000600    0.034405           True
# 17    0.034405         0.000247   -0.037923          False
# 18   -0.037923         0.000256   -0.015832          False
# 19   -0.015832         0.000186    0.003611           True
# 20    0.003611         0.000593    0.063134           True
# 21    0.063134         0.002446    0.118461           True
# 22    0.118461         0.005702    0.028061           True
# 23    0.028061         0.006718    0.020070           True
# 24    0.020070         0.006002    0.101784           True
# 25    0.101784         0.006263   -0.042857          False
# 26   -0.042857         0.004245    0.090050           True
# 27    0.090050         0.003881   -0.019626          False
# 28   -0.019626         0.002507   -0.030261          False
# 29   -0.030261         0.000586   -0.015843          False
#
#     predicted_trend_up  true_prediction
# 0                 True             True
# 1                 True            False
# 2                 True            False
# 3                 True            False
# 4                 True            False
# 5                False            False
# 6                False             True
# 7                False            False
# 8                False            False
# 9                False            False
# 10                True             True
# 11                True             True
# 12                True             True
# 13                True            False
# 14                True            False
# 15                True             True
# 16               False            False
# 17                True            False
# 18                True            False
# 19                True             True
# 20                True             True
# 21                True             True
# 22                True             True
# 23                True             True
# 24                True             True
# 25                True            False
# 26                True             True
# 27                True            False
# 28                True            False
# 29                True            False
